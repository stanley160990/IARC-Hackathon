# %% [markdown]
# # Selamat datang dalam Bootcamp AI untuk Sains
#
# Tujuan dari bootcamp ini adalah untuk memberikan pengantar aplikasi algoritma kecerdasan buatan (AI) dalam komputasi kinerja tinggi ilmiah. Bootcamp ini akan memperkenalkan peserta pada dasar-dasar AI dan bagaimana AI dapat diterapkan ke domain simulasi HPC.
#
# Berikut hal-hal yang akan dibahas selama bootcamp:
# - [CNN Primer dan Keras 101](Intro_to_DL/Part_2.ipynb)
# - [Aliran Steady State menggunakan Neural Networks](CFD/Start_Here.ipynb)
#
# ## Pemeriksaan GPU
#
# Sebelum melanjutkan, kita akan memverifikasi bahwa TensorFlow dapat mendeteksi dan menggunakan GPU Anda.

# %%
# Impor Library yang Diperlukan

from __future__ import absolute_import, division, print_function, unicode_literals

# TensorFlow dan tf.keras
import tensorflow as tf
from tensorflow import keras

# Library pembantu
import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)


tf.test.gpu_device_name()

# %% [markdown]
# Output dari sel di atas akan menampilkan GPU kompatibel yang tersedia di sistem (jika ada beberapa GPU, hanya perangkat 0 yang akan ditampilkan). Jika tidak ada perangkat GPU yang terdaftar atau Anda melihat kesalahan, itu berarti tidak ada GPU yang kompatibel di sistem, dan panggilan selanjutnya dapat berjalan di CPU, menghabiskan lebih banyak waktu.

# %% [markdown]
# ## [CNN Primer dan Keras 101](Intro_to_DL/Part_2.ipynb)
#
# Dalam <i>notebook</i> ini, peserta akan diperkenalkan ke convolutional neural network (CNN) dan cara mengimplementasikannya menggunakan Keras API di TensorFlow. Notebook ini akan berfungsi sebagai titik awal yang baik bagi pemula mutlak untuk jaringan saraf (<i>neural network</i>).
#
# **Setelah menyelesaikan <i>notebook</i> ini diharapkan peserta dapat :**
#
# - Memahami alur pembelajaran mesin
# - Memahami cara kerja jaringan saraf konvolusional
# - Membuat dan melatih klasifikasi deep learning
#
# Untuk pemahaman mendalam tentang konsep deep learning, silakan kunjungi [NVIDIA Deep Learning Institute](https://www.nvidia.com/en-us/deep-learning-ai/education/).

# %% [markdown]
# ## [Steady State Flow menggunakan Neural Networks](CFD/Start_Here.ipynb)
#
# Dalam notebook ini, peserta akan diperkenalkan bagaimana deep learning dapat diterapkan di bidang dinamika fluida.
#
# **Daftar Isi:**
#
# - Memahami pernyataan masalah
# - Membangun alur deep learning
#     - Memahami data dan tugas
#     - Diskusikan berbagai model
#     - Menentukan parameter jaringan saraf
# - Jaringan yang terhubung sepenuhnya
# - Model konvolusional
# - Jaringan canggih
#
# **Setelah menyelesaikan <i>notebook</i> ini diharapkan peserta dapat:**
#
# - Memahami proses penerapan deep learning pada dinamika fluida komputasional
# - Memahami cara kerja blok residual
# - Tolok ukur antara model yang berbeda dan bagaimana mereka membandingkan satu sama lain
#
# ## Licensing
# This material is released by OpenACC-Standard.org, in collaboration with NVIDIA Corporation, under the Creative Commons Attribution 4.0 International (CC BY 4.0).
